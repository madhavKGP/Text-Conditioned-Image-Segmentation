# %%
# Install roboflow
# !pip install roboflow -q

from roboflow import Roboflow
rf = Roboflow(api_key='')
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
project = rf.workspace("madhav-adeu0").project("cracks-3ii36-hshuc")
version = project.version(1)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in cracks-1 to coco:: 100%|██████████| 297367/297367 [00:29<00:00, 10026.91it/s]
# Extracting Dataset Version Zip to cracks-1 in coco:: 100%|██████████| 5374/5374 [00:01<00:00, 3513.11it/s]

# %%
# joint dataset
project = rf.workspace("objectdetect-pu6rn").project("drywall-join-detect")
version = project.version(1)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Drywall-Join-Detect-1 to coco:: 100%|██████████| 32559/32559 [00:05<00:00, 6481.63it/s]
# Extracting Dataset Version Zip to Drywall-Join-Detect-1 in coco:: 100%|██████████| 1192/1192 [00:00<00:00, 3360.24it/s]
